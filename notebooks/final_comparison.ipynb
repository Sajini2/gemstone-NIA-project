# %% [markdown]
# # Final Project Evaluation (NIA Gemstone Price Prediction)
#
# This notebook generates the final comparison tables and visual charts between our baseline models (Random Forest, XGBoost) and our feature-optimized models using Genetic Algorithms (GA) and Particle Swarm Optimization (PSO).

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# Run the evaluation script
# %run ../src/final_evaluation.py

# %% [markdown]
# ### 1. Final Comparison Metrics

# %%
import pandas as pd
from IPython.display import display, HTML

csv_path = '../results/final_comparison.csv'
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    display(HTML(df.to_html(index=False)))
else:
    print("Comparison CSV not found.")

# %% [markdown]
# ### 2. Model Performance Chart

# %%
from IPython.display import Image
display(Image(filename='../results/comparison_metrics_chart.png'))

# %% [markdown]
# ### 3. GA vs PSO Convergence Curves

# %%
display(Image(filename='../results/ga_vs_pso_convergence.png'))

# %% [markdown]
# ### 4. Complexity Comparison

# %%
display(Image(filename='../results/complexity_comparison.png'))

# %% [markdown]
# ### 5. Key Findings Summary

# %%
with open('../results/key_findings.md', 'r') as f:
    for line in f:
        print(line.strip())
